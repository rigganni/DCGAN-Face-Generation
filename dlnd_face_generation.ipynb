# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed-celeba-small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    # resize images based on image_size & convert to tensor
    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.ToTensor()])
    
    # get training data
    train_dataset = datasets.ImageFolder(data_dir, transform=transform)
    
    # define DataLoader for CelebA dataset
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)
    
    return train_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 512
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max -min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.9843)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
# Create helper conv function based on helper function in DCGAN Jupyter Notebook used in class.
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
       Batch normalization set to true by default since used on all outputs on convolution besides the first for the Discriminator
    """
    layers = []
    # Bias is not used in convs for GANs
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        # 32x32 input based on already preprocessed data
        # batch_norm is not used after first conv layer in the Discriminator
        self.conv1 = conv(3, conv_dim, 4, batch_norm=False) # 16x16xconv_dim output
        self.conv2 = conv(conv_dim, conv_dim*2, 4) # 8x8xconvdim*2 output
        self.conv3 = conv(conv_dim*2, conv_dim*4, 4) # 4x4xconvdim*4 output
        self.fc = nn.Linear(conv_dim*4*4*4, 1) # Input size to final, fully connected layter is conv3's output size

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        
        # flatten to input to final, fully connected layter
        x = x.view(-1, self.conv_dim*4*4*4)
        
        # send through final, fully connected layer
        x = self.fc(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# create helper function to deconvolve based on helper function in DCGAN Jupyter Notebook used in class
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    # Bias is not used in convs for GANs
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    # append transpose convolutional layer
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, conv_dim*4*4*4) # Starting with final output size and reducting until down to 3 channels (RGB)
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False) # Want to end up with z_sizexz_sizex3

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4) # batch_size x depth x 4 x 4
        
        x = F.relu(self.t_conv1(x))
        x = F.relu(self.t_conv2(x))
        
        x = self.t_conv3(x)
        x = torch.tanh(x) # Using torch.tanh instead of F.tanh since received warning F.tanh is deprecated
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname in ['Conv', 'Linear']:
      nn.init.normal_(m.weight, mean=0.0, std=0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 128
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=8192, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0) # first dimension is batch_size
    labels = torch.ones(batch_size) # since calculating real loss we know that labels are equal to 1
    # move labels to GPU if using
    if train_on_gpu:
        labels = labels.cuda()
    # chose binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels) # removed batch_size dimension with squeeze
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0) # first dimension is batch_size
    labels = torch.zeros(batch_size) # since calculating fake loss we know that labels are equal to 0
    # move labels to GPU if using
    if train_on_gpu:
        labels = labels.cuda()
    # chose binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels) # removed batch_size dimension with squeeze
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params from DCGAN Jupyter Notebook in class based on DCGAN paper
# beta2 is the default value in optim.Adam
lr = 0.0002
beta1=0.5
beta2=0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            # 1. Train the discriminator on real and fake images
            
            # zero out gradients
            d_optimizer.zero_grad()
            
            # move to GPU if available
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real) # calling real_loss function defined above
            
            # Generate fake images to feed the discrimanator
            z = np.random.uniform(-1, 1, size=(batch_size, z_size)) # z_size defined in hyperparameter settings above; using -1 to 1 since using tanh output and changed pixel values from 0 to 1 to -1 to 1 on real images
            z = torch.from_numpy(z).float()
            # move z to GPU
            if train_on_gpu:
                z = z.cuda()
            # generate the fake fake images
            fake_images = G(z)
            
            # compute discriminator losses on the fake images generated
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake) # calling fake_loss function defined above
            
            # combine fake and real loss for toal discriminator loss
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            # zero out gradients
            g_optimizer.zero_grad()
            
            # generate fake images again
            z = np.random.uniform(-1, 1, size=(batch_size, z_size)) # z_size defined in hyperparameter settings above; using -1 to 1 since using tanh output and changed pixel values from 0 to 1 to -1 to 1 on real images
            z = torch.from_numpy(z).float()
            # move z to GPU
            if train_on_gpu:
                z = z.cuda()
            # generate the fake fake images
            fake_images = G(z)
            
            # compute discrimator loss on fake images using reverse labels
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) 
            
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 100


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/  100] | d_loss: 1.7976 | g_loss: 10.1970
# Epoch [    1/  100] | d_loss: 0.0055 | g_loss: 8.9717
# Epoch [    1/  100] | d_loss: 0.0025 | g_loss: 9.4279
# Epoch [    1/  100] | d_loss: 0.1191 | g_loss: 5.7914
# Epoch [    2/  100] | d_loss: 0.2712 | g_loss: 3.5254
# Epoch [    2/  100] | d_loss: 0.0907 | g_loss: 4.4367
# Epoch [    2/  100] | d_loss: 0.0492 | g_loss: 6.1956
# Epoch [    2/  100] | d_loss: 0.0930 | g_loss: 4.3161
# Epoch [    3/  100] | d_loss: 0.1165 | g_loss: 3.8202
# Epoch [    3/  100] | d_loss: 0.2092 | g_loss: 3.8308
# Epoch [    3/  100] | d_loss: 0.2192 | g_loss: 3.2987
# Epoch [    3/  100] | d_loss: 0.3654 | g_loss: 1.6495
# Epoch [    4/  100] | d_loss: 0.1192 | g_loss: 4.2514
# Epoch [    4/  100] | d_loss: 0.2609 | g_loss: 4.0237
# Epoch [    4/  100] | d_loss: 0.1957 | g_loss: 3.0375
# Epoch [    4/  100] | d_loss: 0.1338 | g_loss: 4.9891
# Epoch [    5/  100] | d_loss: 0.4155 | g_loss: 5.4369
# Epoch [    5/  100] | d_loss: 0.1967 | g_loss: 3.5250
# Epoch [    5/  100] | d_loss: 0.1879 | g_loss: 8.1198
# Epoch [    5/  100] | d_loss: 0.2811 | g_loss: 3.5841
# Epoch [    6/  100] | d_loss: 0.2023 | g_loss: 2.4010
# Epoch [    6/  100] | d_loss: 0.3319 | g_loss: 1.8865
# Epoch [    6/  100] | d_loss: 2.7583 | g_loss: 13.4446
# Epoch [    6/  100] | d_loss: 0.4326 | g_loss: 6.1478
# Epoch [    7/  100] | d_loss: 0.4567 | g_loss: 6.3242
# Epoch [    7/  100] | d_loss: 0.2582 | g_loss: 2.8394
# Epoch [    7/  100] | d_loss: 0.1818 | g_loss: 3.5348
# Epoch [    7/  100] | d_loss: 0.2263 | g_loss: 3.7948
# Epoch [    8/  100] | d_loss: 0.2297 | g_loss: 2.9309
# Epoch [    8/  100] | d_loss: 0.4422 | g_loss: 4.6547
# Epoch [    8/  100] | d_loss: 3.7205 | g_loss: 2.3853
# Epoch [    8/  100] | d_loss: 0.2301 | g_loss: 3.7627
# Epoch [    9/  100] | d_loss: 0.2141 | g_loss: 2.6621
# Epoch [    9/  100] | d_loss: 0.2756 | g_loss: 2.3985
# Epoch [    9/  100] | d_loss: 0.1213 | g_loss: 3.8873
# Epoch [    9/  100] | d_loss: 0.2012 | g_loss: 4.2459
# Epoch [   10/  100] | d_loss: 0.2501 | g_loss: 4.9287
# Epoch [   10/  100] | d_loss: 0.2146 | g_loss: 3.5835
# Epoch [   10/  100] | d_loss: 0.1842 | g_loss: 3.5243
# Epoch [   10/  100] | d_loss: 0.2083 | g_loss: 3.3418
# Epoch [   11/  100] | d_loss: 0.1495 | g_loss: 4.1680
# Epoch [   11/  100] | d_loss: 0.8917 | g_loss: 0.9702
# Epoch [   11/  100] | d_loss: 0.1842 | g_loss: 3.2714
# Epoch [   11/  100] | d_loss: 0.1773 | g_loss: 3.7486
# Epoch [   12/  100] | d_loss: 0.2852 | g_loss: 3.5639
# Epoch [   12/  100] | d_loss: 0.2152 | g_loss: 3.0102
# Epoch [   12/  100] | d_loss: 0.3495 | g_loss: 3.9955
# Epoch [   12/  100] | d_loss: 0.1496 | g_loss: 3.6922
# Epoch [   13/  100] | d_loss: 0.5795 | g_loss: 6.1200
# Epoch [   13/  100] | d_loss: 0.1419 | g_loss: 4.3533
# Epoch [   13/  100] | d_loss: 0.2291 | g_loss: 5.7538
# Epoch [   13/  100] | d_loss: 0.4707 | g_loss: 2.9612
# Epoch [   14/  100] | d_loss: 0.2784 | g_loss: 3.8376
# Epoch [   14/  100] | d_loss: 0.3435 | g_loss: 2.3085
# Epoch [   14/  100] | d_loss: 0.1449 | g_loss: 3.5413
# Epoch [   14/  100] | d_loss: 0.9338 | g_loss: 0.1708
# Epoch [   15/  100] | d_loss: 0.3216 | g_loss: 3.0494
# Epoch [   15/  100] | d_loss: 0.2504 | g_loss: 2.2282
# Epoch [   15/  100] | d_loss: 0.1029 | g_loss: 2.7644
# Epoch [   15/  100] | d_loss: 0.2448 | g_loss: 3.1616
# Epoch [   16/  100] | d_loss: 0.2052 | g_loss: 3.7792
# Epoch [   16/  100] | d_loss: 0.0957 | g_loss: 4.2362
# Epoch [   16/  100] | d_loss: 0.1379 | g_loss: 4.1182
# Epoch [   16/  100] | d_loss: 0.1739 | g_loss: 3.7220
# Epoch [   17/  100] | d_loss: 0.1778 | g_loss: 3.4419
# Epoch [   17/  100] | d_loss: 0.1073 | g_loss: 4.7148
# Epoch [   17/  100] | d_loss: 0.1664 | g_loss: 4.6546
# Epoch [   17/  100] | d_loss: 0.1638 | g_loss: 4.5350
# Epoch [   18/  100] | d_loss: 0.1336 | g_loss: 3.5918
# Epoch [   18/  100] | d_loss: 0.1801 | g_loss: 5.2543
# Epoch [   18/  100] | d_loss: 0.1386 | g_loss: 4.9975
# Epoch [   18/  100] | d_loss: 0.8094 | g_loss: 5.6805
# Epoch [   19/  100] | d_loss: 0.3664 | g_loss: 3.0581
# Epoch [   19/  100] | d_loss: 0.1475 | g_loss: 3.6329
# Epoch [   19/  100] | d_loss: 0.1659 | g_loss: 3.1784
# Epoch [   19/  100] | d_loss: 0.0932 | g_loss: 3.6817
# Epoch [   20/  100] | d_loss: 0.0926 | g_loss: 4.2619
# Epoch [   20/  100] | d_loss: 0.3219 | g_loss: 3.4570
# Epoch [   20/  100] | d_loss: 0.1486 | g_loss: 4.1337
# Epoch [   20/  100] | d_loss: 0.1178 | g_loss: 3.5490
# Epoch [   21/  100] | d_loss: 0.0810 | g_loss: 4.0264
# Epoch [   21/  100] | d_loss: 0.1091 | g_loss: 4.0049
# Epoch [   21/  100] | d_loss: 1.5316 | g_loss: 1.8043
# Epoch [   21/  100] | d_loss: 0.2907 | g_loss: 4.5588
# Epoch [   22/  100] | d_loss: 0.1575 | g_loss: 3.8216
# Epoch [   22/  100] | d_loss: 0.0872 | g_loss: 3.9339
# Epoch [   22/  100] | d_loss: 0.1769 | g_loss: 3.1186
# Epoch [   22/  100] | d_loss: 0.4085 | g_loss: 4.7259
# Epoch [   23/  100] | d_loss: 0.1935 | g_loss: 3.8686
# Epoch [   23/  100] | d_loss: 0.1302 | g_loss: 3.9279
# Epoch [   23/  100] | d_loss: 0.1002 | g_loss: 3.8129
# Epoch [   23/  100] | d_loss: 0.1368 | g_loss: 4.7699
# Epoch [   24/  100] | d_loss: 0.1038 | g_loss: 4.5501
# Epoch [   24/  100] | d_loss: 2.6804 | g_loss: 0.1042
# Epoch [   24/  100] | d_loss: 0.4936 | g_loss: 3.4483
# Epoch [   24/  100] | d_loss: 0.1502 | g_loss: 3.8324
# Epoch [   25/  100] | d_loss: 0.1009 | g_loss: 3.5604
# Epoch [   25/  100] | d_loss: 0.6794 | g_loss: 4.0648
# Epoch [   25/  100] | d_loss: 0.0934 | g_loss: 3.8653
# Epoch [   25/  100] | d_loss: 0.0863 | g_loss: 4.2954
# Epoch [   26/  100] | d_loss: 0.0916 | g_loss: 4.0165
# Epoch [   26/  100] | d_loss: 0.0820 | g_loss: 3.8441
# Epoch [   26/  100] | d_loss: 1.3247 | g_loss: 3.9322
# Epoch [   26/  100] | d_loss: 0.3386 | g_loss: 4.3044
# Epoch [   27/  100] | d_loss: 0.3843 | g_loss: 5.6004
# Epoch [   27/  100] | d_loss: 0.1464 | g_loss: 4.1865
# Epoch [   27/  100] | d_loss: 0.1202 | g_loss: 3.5151
# Epoch [   27/  100] | d_loss: 0.1305 | g_loss: 3.3552
# Epoch [   28/  100] | d_loss: 0.1241 | g_loss: 3.5720
# Epoch [   28/  100] | d_loss: 0.2532 | g_loss: 6.3912
# Epoch [   28/  100] | d_loss: 0.9693 | g_loss: 1.9933
# Epoch [   28/  100] | d_loss: 0.1544 | g_loss: 3.8520
# Epoch [   29/  100] | d_loss: 0.0901 | g_loss: 4.6579
# Epoch [   29/  100] | d_loss: 0.0893 | g_loss: 4.2717
# Epoch [   29/  100] | d_loss: 0.1160 | g_loss: 3.0306
# Epoch [   29/  100] | d_loss: 0.0880 | g_loss: 4.1800
# Epoch [   30/  100] | d_loss: 1.1404 | g_loss: 3.3858
# Epoch [   30/  100] | d_loss: 0.2945 | g_loss: 3.0015
# Epoch [   30/  100] | d_loss: 0.1055 | g_loss: 3.3165
# Epoch [   30/  100] | d_loss: 0.1552 | g_loss: 2.1434
# Epoch [   31/  100] | d_loss: 0.0981 | g_loss: 3.6505
# Epoch [   31/  100] | d_loss: 0.0925 | g_loss: 3.8525
# Epoch [   31/  100] | d_loss: 0.0591 | g_loss: 3.8282
# Epoch [   31/  100] | d_loss: 0.0863 | g_loss: 5.5333
# Epoch [   32/  100] | d_loss: 0.0768 | g_loss: 4.4149
# Epoch [   32/  100] | d_loss: 1.3953 | g_loss: 3.7763
# Epoch [   32/  100] | d_loss: 0.3322 | g_loss: 4.7987
# Epoch [   32/  100] | d_loss: 0.1426 | g_loss: 3.8819
# Epoch [   33/  100] | d_loss: 0.1073 | g_loss: 3.9241
# Epoch [   33/  100] | d_loss: 0.1131 | g_loss: 3.9555
# Epoch [   33/  100] | d_loss: 0.3245 | g_loss: 3.0348
# Epoch [   33/  100] | d_loss: 0.0919 | g_loss: 4.0565
# Epoch [   34/  100] | d_loss: 0.1029 | g_loss: 4.8868
# Epoch [   34/  100] | d_loss: 0.0906 | g_loss: 4.4581
# Epoch [   34/  100] | d_loss: 0.1000 | g_loss: 4.4913
# Epoch [   34/  100] | d_loss: 0.0696 | g_loss: 4.4131
# Epoch [   35/  100] | d_loss: 0.0801 | g_loss: 3.4770
# Epoch [   35/  100] | d_loss: 1.8415 | g_loss: 2.6322
# Epoch [   35/  100] | d_loss: 1.5812 | g_loss: 9.6209
# Epoch [   35/  100] | d_loss: 0.2168 | g_loss: 3.9377
# Epoch [   36/  100] | d_loss: 0.2971 | g_loss: 3.6510
# Epoch [   36/  100] | d_loss: 0.1171 | g_loss: 3.8722
# Epoch [   36/  100] | d_loss: 0.1695 | g_loss: 3.1996
# Epoch [   36/  100] | d_loss: 0.0769 | g_loss: 3.9252
# Epoch [   37/  100] | d_loss: 0.0871 | g_loss: 3.4412
# Epoch [   37/  100] | d_loss: 0.6116 | g_loss: 4.5927
# Epoch [   37/  100] | d_loss: 0.1211 | g_loss: 3.9834
# Epoch [   37/  100] | d_loss: 0.0892 | g_loss: 4.1960
# Epoch [   38/  100] | d_loss: 0.0800 | g_loss: 4.5918
# Epoch [   38/  100] | d_loss: 0.0766 | g_loss: 3.6927
# Epoch [   38/  100] | d_loss: 0.0961 | g_loss: 3.5281
# Epoch [   38/  100] | d_loss: 0.0829 | g_loss: 3.9489
# Epoch [   39/  100] | d_loss: 0.0572 | g_loss: 3.8128
# Epoch [   39/  100] | d_loss: 0.9573 | g_loss: 2.0130
# Epoch [   39/  100] | d_loss: 0.3882 | g_loss: 7.9480
# Epoch [   39/  100] | d_loss: 0.1249 | g_loss: 3.2985
# Epoch [   40/  100] | d_loss: 0.0893 | g_loss: 4.3828
# Epoch [   40/  100] | d_loss: 0.1024 | g_loss: 3.3049
# Epoch [   40/  100] | d_loss: 0.0699 | g_loss: 3.9588
# Epoch [   40/  100] | d_loss: 0.0672 | g_loss: 4.2289
# Epoch [   41/  100] | d_loss: 0.0577 | g_loss: 4.5855
# Epoch [   41/  100] | d_loss: 0.0607 | g_loss: 5.2747
# Epoch [   41/  100] | d_loss: 1.0420 | g_loss: 1.2834
# Epoch [   41/  100] | d_loss: 0.5539 | g_loss: 5.4486
# Epoch [   42/  100] | d_loss: 0.1522 | g_loss: 4.3094
# Epoch [   42/  100] | d_loss: 0.4149 | g_loss: 3.8033
# Epoch [   42/  100] | d_loss: 0.1010 | g_loss: 3.9621
# Epoch [   42/  100] | d_loss: 0.0754 | g_loss: 4.8184
# Epoch [   43/  100] | d_loss: 0.0807 | g_loss: 4.1936
# Epoch [   43/  100] | d_loss: 0.0763 | g_loss: 4.5020
# Epoch [   43/  100] | d_loss: 0.0710 | g_loss: 4.1117
# Epoch [   43/  100] | d_loss: 2.7626 | g_loss: 0.0569
# Epoch [   44/  100] | d_loss: 1.3041 | g_loss: 1.3721
# Epoch [   44/  100] | d_loss: 0.8153 | g_loss: 2.3757
# Epoch [   44/  100] | d_loss: 0.1515 | g_loss: 3.7780
# Epoch [   44/  100] | d_loss: 0.0821 | g_loss: 3.9161
# Epoch [   45/  100] | d_loss: 0.1151 | g_loss: 4.5551
# Epoch [   45/  100] | d_loss: 0.4140 | g_loss: 1.6851
# Epoch [   45/  100] | d_loss: 0.0928 | g_loss: 4.3065
# Epoch [   45/  100] | d_loss: 0.0574 | g_loss: 3.9847
# Epoch [   46/  100] | d_loss: 0.0904 | g_loss: 4.8985
# Epoch [   46/  100] | d_loss: 0.0769 | g_loss: 3.5408
# Epoch [   46/  100] | d_loss: 0.0628 | g_loss: 3.9692
# Epoch [   46/  100] | d_loss: 0.0399 | g_loss: 5.3558
# Epoch [   47/  100] | d_loss: 0.0518 | g_loss: 5.1899
# Epoch [   47/  100] | d_loss: 0.0512 | g_loss: 4.8641
# Epoch [   47/  100] | d_loss: 0.0552 | g_loss: 4.4831
# Epoch [   47/  100] | d_loss: 0.9482 | g_loss: 1.7012
# Epoch [   48/  100] | d_loss: 0.4945 | g_loss: 4.1222
# Epoch [   48/  100] | d_loss: 0.2211 | g_loss: 3.3102
# Epoch [   48/  100] | d_loss: 0.1103 | g_loss: 4.7304
# Epoch [   48/  100] | d_loss: 0.1032 | g_loss: 4.1756
# Epoch [   49/  100] | d_loss: 0.0960 | g_loss: 4.4971
# Epoch [   49/  100] | d_loss: 0.4908 | g_loss: 2.3917
# Epoch [   49/  100] | d_loss: 0.1461 | g_loss: 4.8345
# Epoch [   49/  100] | d_loss: 0.1155 | g_loss: 4.9377
# Epoch [   50/  100] | d_loss: 0.0810 | g_loss: 4.5662
# Epoch [   50/  100] | d_loss: 0.0676 | g_loss: 4.1826
# Epoch [   50/  100] | d_loss: 0.0587 | g_loss: 4.0457
# Epoch [   50/  100] | d_loss: 0.0711 | g_loss: 3.9752
# Epoch [   51/  100] | d_loss: 0.0573 | g_loss: 4.2331
# Epoch [   51/  100] | d_loss: 0.0617 | g_loss: 4.6697
# Epoch [   51/  100] | d_loss: 0.0588 | g_loss: 4.0360
# Epoch [   51/  100] | d_loss: 0.0517 | g_loss: 4.6490
# Epoch [   52/  100] | d_loss: 0.0524 | g_loss: 5.2871
# Epoch [   52/  100] | d_loss: 0.0424 | g_loss: 4.3993
# Epoch [   52/  100] | d_loss: 1.1939 | g_loss: 3.6334
# Epoch [   52/  100] | d_loss: 0.6388 | g_loss: 3.7870
# Epoch [   53/  100] | d_loss: 0.8245 | g_loss: 1.8358
# Epoch [   53/  100] | d_loss: 0.1339 | g_loss: 4.5995
# Epoch [   53/  100] | d_loss: 0.0973 | g_loss: 4.3555
# Epoch [   53/  100] | d_loss: 0.3027 | g_loss: 3.5962
# Epoch [   54/  100] | d_loss: 0.1315 | g_loss: 4.1038
# Epoch [   54/  100] | d_loss: 0.0794 | g_loss: 4.0310
# Epoch [   54/  100] | d_loss: 0.0617 | g_loss: 4.0903
# Epoch [   54/  100] | d_loss: 0.0500 | g_loss: 4.1267
# Epoch [   55/  100] | d_loss: 0.0490 | g_loss: 4.6989
# Epoch [   55/  100] | d_loss: 0.0782 | g_loss: 5.4628
# Epoch [   55/  100] | d_loss: 0.0531 | g_loss: 4.9848
# Epoch [   55/  100] | d_loss: 0.0434 | g_loss: 4.5569
# Epoch [   56/  100] | d_loss: 0.1093 | g_loss: 3.9417
# Epoch [   56/  100] | d_loss: 0.0375 | g_loss: 4.9135
# Epoch [   56/  100] | d_loss: 0.7540 | g_loss: 2.3196
# Epoch [   56/  100] | d_loss: 0.3303 | g_loss: 4.2665
# Epoch [   57/  100] | d_loss: 0.0821 | g_loss: 5.1764
# Epoch [   57/  100] | d_loss: 0.0678 | g_loss: 4.4479
# Epoch [   57/  100] | d_loss: 0.0629 | g_loss: 4.3947
# Epoch [   57/  100] | d_loss: 0.0527 | g_loss: 4.5269
# Epoch [   58/  100] | d_loss: 0.0438 | g_loss: 5.1435
# Epoch [   58/  100] | d_loss: 0.0402 | g_loss: 5.3670
# Epoch [   58/  100] | d_loss: 0.0405 | g_loss: 5.0705
# Epoch [   58/  100] | d_loss: 0.0865 | g_loss: 8.0126
# Epoch [   59/  100] | d_loss: 1.3924 | g_loss: 5.8157
# Epoch [   59/  100] | d_loss: 0.7747 | g_loss: 1.8791
# Epoch [   59/  100] | d_loss: 0.2078 | g_loss: 3.8751
# Epoch [   59/  100] | d_loss: 0.1277 | g_loss: 4.8503
# Epoch [   60/  100] | d_loss: 0.0862 | g_loss: 4.1706
# Epoch [   60/  100] | d_loss: 0.7283 | g_loss: 2.4663
# Epoch [   60/  100] | d_loss: 0.1260 | g_loss: 3.7047
# Epoch [   60/  100] | d_loss: 0.0864 | g_loss: 3.8963
# Epoch [   61/  100] | d_loss: 0.0670 | g_loss: 5.0769
# Epoch [   61/  100] | d_loss: 0.0638 | g_loss: 3.7380
# Epoch [   61/  100] | d_loss: 0.0567 | g_loss: 4.1303
# Epoch [   61/  100] | d_loss: 0.1023 | g_loss: 3.3948
# Epoch [   62/  100] | d_loss: 0.0398 | g_loss: 4.6391
# Epoch [   62/  100] | d_loss: 0.0423 | g_loss: 4.9991
# Epoch [   62/  100] | d_loss: 0.0510 | g_loss: 4.8732
# Epoch [   62/  100] | d_loss: 1.6465 | g_loss: 3.2281
# Epoch [   63/  100] | d_loss: 0.6777 | g_loss: 4.0480
# Epoch [   63/  100] | d_loss: 0.2021 | g_loss: 3.5894
# Epoch [   63/  100] | d_loss: 0.0984 | g_loss: 3.5002
# Epoch [   63/  100] | d_loss: 0.0774 | g_loss: 4.5074
# Epoch [   64/  100] | d_loss: 0.0828 | g_loss: 5.0784
# Epoch [   64/  100] | d_loss: 0.3917 | g_loss: 2.3695
# Epoch [   64/  100] | d_loss: 0.0883 | g_loss: 3.8753
# Epoch [   64/  100] | d_loss: 0.0613 | g_loss: 4.5936
# Epoch [   65/  100] | d_loss: 0.0529 | g_loss: 4.4203
# Epoch [   65/  100] | d_loss: 0.0608 | g_loss: 4.3229
# Epoch [   65/  100] | d_loss: 0.0453 | g_loss: 4.6763
# Epoch [   65/  100] | d_loss: 0.0395 | g_loss: 5.2457
# Epoch [   66/  100] | d_loss: 0.0343 | g_loss: 5.3311
# Epoch [   66/  100] | d_loss: 0.0496 | g_loss: 5.0678
# Epoch [   66/  100] | d_loss: 0.0364 | g_loss: 4.8563
# Epoch [   66/  100] | d_loss: 0.0291 | g_loss: 5.3918
# Epoch [   67/  100] | d_loss: 0.0195 | g_loss: 5.5972
# Epoch [   67/  100] | d_loss: 0.0249 | g_loss: 6.0896
# Epoch [   67/  100] | d_loss: 0.0274 | g_loss: 5.9812
# Epoch [   67/  100] | d_loss: 0.0352 | g_loss: 5.1248
# Epoch [   68/  100] | d_loss: 0.0307 | g_loss: 5.6572
# Epoch [   68/  100] | d_loss: 0.0216 | g_loss: 5.7568
# Epoch [   68/  100] | d_loss: 0.0285 | g_loss: 5.9071
# Epoch [   68/  100] | d_loss: 0.0345 | g_loss: 5.4893
# Epoch [   69/  100] | d_loss: 0.0210 | g_loss: 6.2390
# Epoch [   69/  100] | d_loss: 0.0196 | g_loss: 6.0038
# Epoch [   69/  100] | d_loss: 0.0238 | g_loss: 5.6470
# Epoch [   69/  100] | d_loss: 1.4739 | g_loss: 2.8314
# Epoch [   70/  100] | d_loss: 0.8915 | g_loss: 6.8258
# Epoch [   70/  100] | d_loss: 0.4943 | g_loss: 6.4394
# Epoch [   70/  100] | d_loss: 0.1388 | g_loss: 4.4920
# Epoch [   70/  100] | d_loss: 0.4509 | g_loss: 3.8342
# Epoch [   71/  100] | d_loss: 0.2695 | g_loss: 4.5241
# Epoch [   71/  100] | d_loss: 0.1185 | g_loss: 4.1681
# Epoch [   71/  100] | d_loss: 0.0713 | g_loss: 4.7904
# Epoch [   71/  100] | d_loss: 0.0495 | g_loss: 3.6694
# Epoch [   72/  100] | d_loss: 0.0651 | g_loss: 4.7050
# Epoch [   72/  100] | d_loss: 0.0726 | g_loss: 5.1592
# Epoch [   72/  100] | d_loss: 0.0842 | g_loss: 3.7861
# Epoch [   72/  100] | d_loss: 0.0432 | g_loss: 4.8395
# Epoch [   73/  100] | d_loss: 0.0515 | g_loss: 5.2104
# Epoch [   73/  100] | d_loss: 0.7641 | g_loss: 1.6354
# Epoch [   73/  100] | d_loss: 0.4144 | g_loss: 5.6520
# Epoch [   73/  100] | d_loss: 0.1119 | g_loss: 3.8802
# Epoch [   74/  100] | d_loss: 0.0954 | g_loss: 4.1357
# Epoch [   74/  100] | d_loss: 0.1644 | g_loss: 3.5221
# Epoch [   74/  100] | d_loss: 0.0674 | g_loss: 4.7796
# Epoch [   74/  100] | d_loss: 0.0551 | g_loss: 5.0119
# Epoch [   75/  100] | d_loss: 0.0664 | g_loss: 4.8347
# Epoch [   75/  100] | d_loss: 0.0586 | g_loss: 4.8039
# Epoch [   75/  100] | d_loss: 0.0519 | g_loss: 4.6176
# Epoch [   75/  100] | d_loss: 0.0399 | g_loss: 5.3778
# Epoch [   76/  100] | d_loss: 0.0325 | g_loss: 5.3537
# Epoch [   76/  100] | d_loss: 0.0322 | g_loss: 5.5057
# Epoch [   76/  100] | d_loss: 0.0161 | g_loss: 5.6910
# Epoch [   76/  100] | d_loss: 0.0283 | g_loss: 5.6674
# Epoch [   77/  100] | d_loss: 0.0556 | g_loss: 4.9216
# Epoch [   77/  100] | d_loss: 0.0302 | g_loss: 5.6977
# Epoch [   77/  100] | d_loss: 0.0286 | g_loss: 5.7503
# Epoch [   77/  100] | d_loss: 1.6360 | g_loss: 1.7662
# Epoch [   78/  100] | d_loss: 0.7726 | g_loss: 3.4516
# Epoch [   78/  100] | d_loss: 0.6512 | g_loss: 6.5387
# Epoch [   78/  100] | d_loss: 0.2194 | g_loss: 4.1566
# Epoch [   78/  100] | d_loss: 1.6344 | g_loss: 9.1378
# Epoch [   79/  100] | d_loss: 0.1678 | g_loss: 4.3096
# Epoch [   79/  100] | d_loss: 0.0767 | g_loss: 5.2144
# Epoch [   79/  100] | d_loss: 0.0638 | g_loss: 5.2878
# Epoch [   79/  100] | d_loss: 0.0666 | g_loss: 4.3036
# Epoch [   80/  100] | d_loss: 0.0599 | g_loss: 5.1189
# Epoch [   80/  100] | d_loss: 0.0507 | g_loss: 5.3082
# Epoch [   80/  100] | d_loss: 0.8393 | g_loss: 1.8168
# Epoch [   80/  100] | d_loss: 0.3034 | g_loss: 3.6180
# Epoch [   81/  100] | d_loss: 0.2239 | g_loss: 2.9583
# Epoch [   81/  100] | d_loss: 0.1502 | g_loss: 4.6111
# Epoch [   81/  100] | d_loss: 0.0672 | g_loss: 4.4347
# Epoch [   81/  100] | d_loss: 0.0519 | g_loss: 4.3300
# Epoch [   82/  100] | d_loss: 0.0622 | g_loss: 4.5934
# Epoch [   82/  100] | d_loss: 0.0564 | g_loss: 4.6858
# Epoch [   82/  100] | d_loss: 0.0484 | g_loss: 4.6587
# Epoch [   82/  100] | d_loss: 0.0419 | g_loss: 4.4628
# Epoch [   83/  100] | d_loss: 0.0386 | g_loss: 5.5260
# Epoch [   83/  100] | d_loss: 0.0277 | g_loss: 5.5803
# Epoch [   83/  100] | d_loss: 0.0357 | g_loss: 5.1339
# Epoch [   83/  100] | d_loss: 0.0253 | g_loss: 5.5521
# Epoch [   84/  100] | d_loss: 0.0264 | g_loss: 6.4321
# Epoch [   84/  100] | d_loss: 0.0229 | g_loss: 5.9215
# Epoch [   84/  100] | d_loss: 0.0203 | g_loss: 5.9968
# Epoch [   84/  100] | d_loss: 0.0217 | g_loss: 6.4718
# Epoch [   85/  100] | d_loss: 0.0223 | g_loss: 7.3965
# Epoch [   85/  100] | d_loss: 0.0298 | g_loss: 6.9907
# Epoch [   85/  100] | d_loss: 0.0170 | g_loss: 7.7906
# Epoch [   85/  100] | d_loss: 0.0064 | g_loss: 8.2003
# Epoch [   86/  100] | d_loss: 0.0053 | g_loss: 8.3587
# Epoch [   86/  100] | d_loss: 0.0061 | g_loss: 8.8198
# Epoch [   86/  100] | d_loss: 0.0034 | g_loss: 8.8706
# Epoch [   86/  100] | d_loss: 0.0045 | g_loss: 10.7418
# Epoch [   87/  100] | d_loss: 0.0029 | g_loss: 9.9862
# Epoch [   87/  100] | d_loss: 0.0040 | g_loss: 9.4201
# Epoch [   87/  100] | d_loss: 0.0036 | g_loss: 9.6745
# Epoch [   87/  100] | d_loss: 0.0032 | g_loss: 8.9899
# Epoch [   88/  100] | d_loss: 0.0031 | g_loss: 9.0471
# Epoch [   88/  100] | d_loss: 0.0026 | g_loss: 9.0528
# Epoch [   88/  100] | d_loss: 0.0021 | g_loss: 9.9561
# Epoch [   88/  100] | d_loss: 0.0031 | g_loss: 9.0437
# Epoch [   89/  100] | d_loss: 0.0013 | g_loss: 9.1273
# Epoch [   89/  100] | d_loss: 0.0014 | g_loss: 9.5712
# Epoch [   89/  100] | d_loss: 0.0011 | g_loss: 9.4141
# Epoch [   89/  100] | d_loss: 0.0011 | g_loss: 9.4165
# Epoch [   90/  100] | d_loss: 0.0011 | g_loss: 9.1215
# Epoch [   90/  100] | d_loss: 0.0010 | g_loss: 9.4095
# Epoch [   90/  100] | d_loss: 0.0009 | g_loss: 9.4093
# Epoch [   90/  100] | d_loss: 0.0008 | g_loss: 9.6453
# Epoch [   91/  100] | d_loss: 0.0006 | g_loss: 9.2169
# Epoch [   91/  100] | d_loss: 0.0009 | g_loss: 9.5164
# Epoch [   91/  100] | d_loss: 0.0045 | g_loss: 8.9961
# Epoch [   91/  100] | d_loss: 0.0012 | g_loss: 10.5245
# Epoch [   92/  100] | d_loss: 0.0072 | g_loss: 18.0282
# Epoch [   92/  100] | d_loss: 0.0062 | g_loss: 11.8070
# Epoch [   92/  100] | d_loss: 0.0011 | g_loss: 9.6433
# Epoch [   92/  100] | d_loss: 0.0024 | g_loss: 9.0436
# Epoch [   93/  100] | d_loss: 0.0007 | g_loss: 9.3833
# Epoch [   93/  100] | d_loss: 0.0027 | g_loss: 10.5087
# Epoch [   93/  100] | d_loss: 0.0008 | g_loss: 9.8590
# Epoch [   93/  100] | d_loss: 0.0007 | g_loss: 9.2603
# Epoch [   94/  100] | d_loss: 0.0013 | g_loss: 9.5841
# Epoch [   94/  100] | d_loss: 0.0008 | g_loss: 10.0667
# Epoch [   94/  100] | d_loss: 0.0010 | g_loss: 9.4139
# Epoch [   94/  100] | d_loss: 0.0011 | g_loss: 8.9563
# Epoch [   95/  100] | d_loss: 0.0009 | g_loss: 9.4154
# Epoch [   95/  100] | d_loss: 0.0036 | g_loss: 8.8141
# Epoch [   95/  100] | d_loss: 0.0008 | g_loss: 9.9298
# Epoch [   95/  100] | d_loss: 0.0007 | g_loss: 9.5321
# Epoch [   96/  100] | d_loss: 0.0010 | g_loss: 8.9276
# Epoch [   96/  100] | d_loss: 0.0586 | g_loss: 40.9980
# Epoch [   96/  100] | d_loss: 0.0426 | g_loss: 44.9818
# Epoch [   96/  100] | d_loss: 0.0099 | g_loss: 11.0388
# Epoch [   97/  100] | d_loss: 0.0123 | g_loss: 9.5575
# Epoch [   97/  100] | d_loss: 0.0028 | g_loss: 17.4548
# Epoch [   97/  100] | d_loss: 0.0030 | g_loss: 8.6085
# Epoch [   97/  100] | d_loss: 0.0024 | g_loss: 9.2610
# Epoch [   98/  100] | d_loss: 0.0057 | g_loss: 8.2684
# Epoch [   98/  100] | d_loss: 0.0038 | g_loss: 8.0425
# Epoch [   98/  100] | d_loss: 0.0054 | g_loss: 7.9364
# Epoch [   98/  100] | d_loss: 0.0207 | g_loss: 7.3956
# Epoch [   99/  100] | d_loss: 0.0560 | g_loss: 6.3149
# Epoch [   99/  100] | d_loss: 0.0317 | g_loss: 7.1318
# Epoch [   99/  100] | d_loss: 0.0199 | g_loss: 6.7739
# Epoch [   99/  100] | d_loss: 0.0135 | g_loss: 7.4651
# Epoch [  100/  100] | d_loss: 0.0127 | g_loss: 7.0436
# Epoch [  100/  100] | d_loss: 0.0099 | g_loss: 7.4990
# Epoch [  100/  100] | d_loss: 0.0072 | g_loss: 8.7355
# Epoch [  100/  100] | d_loss: 0.0086 | g_loss: 7.1054

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
